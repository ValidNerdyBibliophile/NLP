#  'The most thing i like about Naruto is that lots of people believe that Naruto can bring peace to the \nninja world.']

# %%
words = nltk.word_tokenize(paragraph)

# %%
words
# Out:
# ['My',
#  'hero',
#  'is',
#  'Naruto',
#  'Uzumaki',
#  '.',
#  'When',
#  'Naruto',
#  'was',
#  'a',
#  'child',
#  'he',
#  'did',
#  "n't",
#  'get',
#  'used',
#  'to',
#  'people',
#  ',',
#  'he',
#  'was',
#  'always',
#  'a',
#  'goof',
#  'ball',
#  'cause',
#  'he',
#  'wanted',
#  'people',
#  'to',
#  'know',
#  'his',
#  'name',
#  'and',
#  'who',
#  'he',
#  'really',
#  'is',
#  '.',
#  'But',
#  'the',
#  'people',
#  'in',
#  'the',
#  'village',
#  'do',
#  "n't",
#  'like',
#  'him',
#  'cause',
#  'there',
#  'was',
#  'a',
#  'monster',
#  'inside',
#  'him',
#  'that',
#  'his',
#  'parents',
#  'sealed',
#  'away',
#  'in',
#  'order',
#  'to',
#  'protect',
#  'their',
#  'village',
#  '.',
#  'The',
#  'people',
#  'call',
#  'the',
#  'monster',
#  'Nine',
#  'Tail',
#  'Fox',
#  'cause',
#  'they',
#  'do',
#  "n't",
#  'know',
#  'his',
#  'original',
#  'name',
#  '.',
#  'They',
#  'only',
#  'name',
#  'him',
#  'that',
#  'cause',
#  'he',
#  "'s",
#  'a',
#  'fox',
#  'and',
#  'he',
#  'has',
#  'nine',
#  'tails',
#  '.',
#  'Nine',
#  'Tail',
#  'Fox',
#  "'s",
#  'original',
#  'name',
#  'is',
#  'Kurama',
#  '.',
#  'When',
#  'Naruto',
#  'grew',
#  'age',
#  'by',
#  'age',
#  'he',
#  'learned',
#  'that',
#  'the',
#  'only',
#  'way',
#  'he',
#  'can',
#  'get',
#  'some',
#  'respect',
#  'and',
#  'so',
#  'people',
#  'can',
#  'know',
#  'who',
#  'he',
#  'is',
#  'to',
#  'become',
#  'a',
#  'hokage',
#  '.',
#  'A',
#  'hokage',
#  'is',
#  'like',
#  'a',
#  'leader',
#  'of',
#  'the',
#  'village',
#  '.',
#  'But',
#  'in',
#  'order',
#  'to',
#  'become',
#  'hokage',
#  'you',
#  'have',
#  'to',
#  'rank',
#  'up',
#  'to',
#  'it',
#  'and',
#  'become',
#  'one',
#  'of',
#  'the',
#  'strongest',
#  'persons',
#  'in',
#  'the',
#  'village',
#  'and',
#  'the',
#  'best',
#  'person',
#  'who',
#  'can',
#  'lead',
#  'it',
#  '.',
#  'Naruto',
#  'is',
#  'still',
#  'in',
#  'training',
#  'so',
#  'he',
#  'ca',
#  "n't",
#  'become',
#  'a',
#  'ninja',
#  'yet',
#  '.',
#  'At',
#  'the',
#  'age',
#  'of',
#  '12',
#  'Naruto',
#  'was',
#  'able',
#  'to',
#  'pass',
#  'his',
#  'test',
#  'and',
#  'rank',
#  'up',
#  'to',
#  'a',
#  'ninja',
#  '.',
#  'When',
#  'Naruto',
#  'became',
#  'a',
#  'ninja',
#  'he',
#  'was',
#  'put',
#  'in',
#  'a',
#  'team',
#  'of',
#  'a',
#  'group',
#  'of',
#  '4',
#  'people',
#  '.',
#  'The',
#  'group',
#  'was',
#  'always',
#  'two',
#  'men',
#  'and',
#  'one',
#  'woman',
#  'the',
#  'last',
#  'one',
#  'is',
#  'the',
#  'sensei',
#  '.',
#  'The',
#  'sensei',
#  'can',
#  'be',
#  'a',
#  'man',
#  'or',
#  'a',
#  'woman',
#  '.',
#  'Naruto',
#  'sensei',
#  'name',
#  'is',
#  'Kakashi',
#  '.',
#  'Naruto',
#  'team',
#  'was',
#  'name',
#  'Team',
#  '7',
#  '.',
#  'Team',
#  '7',
#  'had',
#  'lots',
#  'of',
#  'missions',
#  'and',
#  'every',
#  'mission',
#  'they',
#  'do',
#  'that',
#  'is',
#  'dangerous',
#  'Naruto',
#  'has',
#  'made',
#  'friends',
#  'with',
#  'them',
#  'even',
#  'if',
#  'they',
#  "'re",
#  'from',
#  'different',
#  'villages',
#  '.',
#  'Naruto',
#  'wants',
#  'to',
#  'accomplish',
#  'his',
#  'dream',
#  'to',
#  'become',
#  'the',
#  'best',
#  'hokage',
#  'ever.When',
#  'Naruto',
#  'starts',
#  'growing',
#  'up',
#  'he',
#  'starts',
#  'to',
#  'make',
#  'friends',
#  'with',
#  'other',
#  'ninja',
#  'teams',
#  '.',
#  'His',
#  'friend',
#  'starts',
#  'to',
#  'get',
#  'jealous',
#  'of',
#  'him',
#  'cause',
#  'Naruto',
#  'was',
#  'stronger',
#  'than',
#  'they',
#  'could',
#  'never',
#  'imagine',
#  '.',
#  'His',
#  'friends',
#  'knew',
#  'that',
#  'he',
#  'had',
#  'the',
#  'Nine',
#  'Tail',
#  'Fox',
#  'in',
#  'him',
#  'but',
#  'they',
#  'did',
#  "n't",
#  'care',
#  'cause',
#  'they',
#  'acknowledged',
#  'him',
#  'for',
#  'who',
#  'he',
#  'is',
#  '.',
#  'When',
#  'Naruto',
#  'turned',
#  'the',
#  'age',
#  'of',
#  '16',
#  'he',
#  'was',
#  'a',
#  'stronger',
#  'and',
#  'greater',
#  'person',
#  '.',
#  'He',
#  'became',
#  'his',
#  'village',
#  'hero',
#  'and',
#  'he',
#  'protects',
#  'lots',
#  'and',
#  'lots',
#  'of',
#  'people',
#  '.',
#  'I',
#  'acknowledge',
#  'Naruto',
#  'Uzumaki',
#  'cause',
#  'he',
#  'is',
#  'a',
#  'person',
#  'who',
#  'never',
#  'gives',
#  'up',
#  'and',
#  'a',
#  'person',
#  'who',
#  'loves',
#  'his',
#  'parents',
#  'and',
#  'protects',
#  'his',
#  'friends',
#  'and',
#  'people',
#  '.',
#  'The',
#  'most',
#  'thing',
#  'i',
#  'like',
#  'about',
#  'Naruto',
#  'is',
#  'that',
#  'lots',
#  'of',
#  'people',
#  'believe',
#  'that',
#  'Naruto',
#  'can',
#  'bring',
#  'peace',
#  'to',
#  'the',
#  'ninja',
#  'world',
#  '.']
